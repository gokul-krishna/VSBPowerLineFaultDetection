# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai import *
from fastai.vision import *

# %%
data = ImageDataBunch.from_folder(Path('data/train_fastai/'), valid_pct=0.15,
                                  ds_tfms=[], size=500, bs=32)

# %%
data.normalize(imagenet_stats);

# %%
data.show_batch(rows=4, figsize=(12, 12))

# %%
learn = create_cnn(data, models.resnet34, metrics=[error_rate, accuracy])

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>error_rate</th>
#     <th>accuracy</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='22' class='' max='270', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       8.15% [22/270 00:18<03:33 0.0000]
#     </div>

# %%
learn.fit_one_cycle(2, max_lr=1e-2)
